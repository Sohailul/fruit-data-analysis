# %%
import numpy as np
import pandas as pnd
import matplotlib.pyplot as plt
import seaborn as snb

# %%
df = pnd.read_csv('fruit_dataset_classification.csv')

# %%
df
# Out:
#     col-1     col-2             col-3  col-4  col-5  col-6  col-7
# 0       1     apple      granny_smith    192    8.4    7.3   0.55
# 1       1     apple      granny_smith    180    8.0    6.8   0.59
# 2       1     apple      granny_smith    176    7.4    7.2   0.60
# 3       2  mandarin          mandarin     86    6.2    0.0   0.80
# 4       2  mandarin          mandarin     84    6.0    4.6   0.79
# 5       2  mandarin          mandarin     80    5.8    4.3   0.77
# 6       2  mandarin          mandarin     80    5.9    4.3   0.81
# 7       2  mandarin          mandarin     76    5.8    4.0   0.81
# 8       1     apple          braeburn      0    7.1    7.8   0.00
# 9       1     apple          braeburn    172    0.0    7.0   0.89
# 10      1     apple          braeburn    166    6.9    7.3   0.93
# 11      1     apple          braeburn    172    7.1    7.6   0.92
# 12      1     apple          braeburn    154    7.0    7.1   0.00
# ...

# %%
x = df.drop(['col-2'],axis = 1)

# %%
x
# Out:
#        col-1     col-3     col-4     col-5     col-6     col-7
# 0   0.000000  0.000000  0.530387  0.875000  0.695238  0.591398
# 1   0.000000  0.000000  0.497238  0.833333  0.647619  0.634409
# 2   0.000000  0.000000  0.486188  0.770833  0.685714  0.645161
# 3   0.333333  0.111111  0.237569  0.645833  0.000000  0.860215
# 4   0.333333  0.111111  0.232044  0.625000  0.438095  0.849462
# 5   0.333333  0.111111  0.220994  0.604167  0.409524  0.827957
# 6   0.333333  0.111111  0.220994  0.614583  0.409524  0.870968
# 7   0.333333  0.111111  0.209945  0.604167  0.380952  0.870968
# 8   0.000000  0.222222  0.000000  0.739583  0.742857  0.000000
# 9   0.000000  0.222222  0.475138  0.000000  0.666667  0.956989
# 10  0.000000  0.222222  0.458564  0.718750  0.695238  1.000000
# 11  0.000000  0.222222  0.475138  0.739583  0.723810  0.989247
# 12  0.000000  0.222222  0.425414  0.729167  0.676190  0.000000
# 13  0.000000  0.333333  0.453039  0.760417  0.733333  0.752688
# ...

# %% [markdown]
# # Converted 3rd Coloum to numerical value

# %%
df['col-3'].replace({"granny_smith": 1 , "mandarin": 2 , "braeburn": 3 , "golden_delicious": 4, "cripps_pink": 5 , "spanish_jumbo": 6 , "selected_seconds": 7 , "turkey_navel": 8 , "spanish_belsan": 9 , "unknown": 10},inplace = True)

# %%
df
# Out:
#     col-1     col-2  col-3  col-4  col-5  col-6  col-7
# 0       1     apple      1    192    8.4    7.3   0.55
# 1       1     apple      1    180    8.0    6.8   0.59
# 2       1     apple      1    176    7.4    7.2   0.60
# 3       2  mandarin      2     86    6.2    0.0   0.80
# 4       2  mandarin      2     84    6.0    4.6   0.79
# 5       2  mandarin      2     80    5.8    4.3   0.77
# 6       2  mandarin      2     80    5.9    4.3   0.81
# 7       2  mandarin      2     76    5.8    4.0   0.81
# 8       1     apple      3      0    7.1    7.8   0.00
# 9       1     apple      3    172    0.0    7.0   0.89
# 10      1     apple      3    166    6.9    7.3   0.93
# 11      1     apple      3    172    7.1    7.6   0.92
# 12      1     apple      3    154    7.0    7.1   0.00
# 13      1     apple      4    164    7.3    7.7   0.70
# 14      1     apple      4    152    7.6    7.3   0.69
# 15      1     apple      4    156    7.7    7.1   0.69
# ...

# %% [markdown]
# # Missing Value count

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col-1   59 non-null     int64
#  1   col-2   59 non-null     object
#  2   col-3   59 non-null     int64
#  3   col-4   59 non-null     int64
#  4   col-5   59 non-null     float64
#  5   col-6   59 non-null     float64
#  6   col-7   59 non-null     float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.4+ KB

# %%
df.isnull().sum()
# Out:
# col-1    0
# col-2    0
# col-3    0
# col-4    0
# col-5    0
# col-6    0
# col-7    0
# dtype: int64

# %% [markdown]
# # Balanced or not checking

# %%
df['col-1'].value_counts()
# Out:
# 0.666667    19
# 0.000000    19
# 1.000000    16
# 0.333333     5
# Name: col-1, dtype: int64

# %%
df['col-1'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
y = df['col-1']

# %%
y
# Out:
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     0.333333
# 4     0.333333
# 5     0.333333
# 6     0.333333
# 7     0.333333
# 8     0.000000
# 9     0.000000
# 10    0.000000
# 11    0.000000
# 12    0.000000
# 13    0.000000
# 14    0.000000
# 15    0.000000
# 16    0.000000
# 17    0.000000
# 18    0.000000
# 19    0.000000
# 20    0.000000
# 21    0.000000
# 22    0.000000
# 23    0.000000
# 24    0.666667
# 25    0.666667
# 26    0.666667
# 27    0.666667
# 28    0.666667
# 29    0.666667
# 30    0.666667
# 31    0.666667
# 32    0.666667
# 33    0.666667
# 34    0.666667
# 35    0.666667
# 36    0.666667
# 37    0.666667
# 38    0.666667
# 39    0.666667
# 40    0.666667
# 41    0.666667
# 42    0.666667
# 43    1.000000
# 44    1.000000
# 45    1.000000
# 46    1.000000
# 47    1.000000
# 48    1.000000
# 49    1.000000
# 50    1.000000
# 51    1.000000
# 52    1.000000
# 53    1.000000
# 54    1.000000
# 55    1.000000
# 56    1.000000
# 57    1.000000
# ...

# %% [markdown]
# # Scalling

# %%
from sklearn.preprocessing import MinMaxScaler
MinMaxScaler = MinMaxScaler()
columns_to_scale = ['col-1','col-3','col-4','col-5','col-6','col-7']
df[columns_to_scale] = MinMaxScaler.fit_transform(df[columns_to_scale])

# %%
df[columns_to_scale]
# Out:
#        col-1     col-3     col-4     col-5     col-6     col-7
# 0   0.000000  0.000000  0.530387  0.875000  0.695238  0.591398
# 1   0.000000  0.000000  0.497238  0.833333  0.647619  0.634409
# 2   0.000000  0.000000  0.486188  0.770833  0.685714  0.645161
# 3   0.333333  0.111111  0.237569  0.645833  0.000000  0.860215
# 4   0.333333  0.111111  0.232044  0.625000  0.438095  0.849462
# 5   0.333333  0.111111  0.220994  0.604167  0.409524  0.827957
# 6   0.333333  0.111111  0.220994  0.614583  0.409524  0.870968
# 7   0.333333  0.111111  0.209945  0.604167  0.380952  0.870968
# 8   0.000000  0.222222  0.000000  0.739583  0.742857  0.000000
# 9   0.000000  0.222222  0.475138  0.000000  0.666667  0.956989
# 10  0.000000  0.222222  0.458564  0.718750  0.695238  1.000000
# 11  0.000000  0.222222  0.475138  0.739583  0.723810  0.989247
# 12  0.000000  0.222222  0.425414  0.729167  0.676190  0.000000
# 13  0.000000  0.333333  0.453039  0.760417  0.733333  0.752688
# ...

# %% [markdown]
# # Training

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=20)

# %%
x_train
# Out:
#        col-1     col-3     col-4     col-5     col-6     col-7
# 52  1.000000  1.000000  0.325967  0.614583  0.761905  0.774194
# 5   0.333333  0.111111  0.220994  0.604167  0.409524  0.827957
# 24  0.666667  0.555556  0.944751  0.000000  0.895238  0.806452
# 36  0.666667  0.777778  0.441989  0.739583  0.723810  0.817204
# 44  1.000000  0.888889  0.552486  0.760417  1.000000  0.774194
# 2   0.000000  0.000000  0.486188  0.770833  0.685714  0.645161
# 49  1.000000  1.000000  0.364641  0.604167  0.828571  0.784946
# 18  0.000000  0.444444  0.447514  0.781250  0.676190  0.000000
# 8   0.000000  0.222222  0.000000  0.739583  0.742857  0.000000
# 1   0.000000  0.000000  0.497238  0.833333  0.647619  0.634409
# 29  0.666667  0.666667  0.441989  0.729167  0.704762  0.870968
# 54  1.000000  1.000000  0.000000  0.635417  0.809524  0.000000
# 51  1.000000  1.000000  0.320442  0.625000  0.714286  0.774194
# 58  1.000000  1.000000  0.325967  0.635417  0.771429  0.752688
# ...

# %%
x_test
# Out:
#        col-1     col-3     col-4     col-5     col-6     col-7
# 4   0.333333  0.111111  0.232044  0.625000  0.438095  0.849462
# 23  0.000000  0.444444  0.469613  0.791667  0.752381  0.946237
# 17  0.000000  0.333333  0.464088  0.000000  0.723810  0.784946
# 56  1.000000  1.000000  0.320442  0.614583  0.771429  0.784946
# 37  0.666667  0.777778  0.000000  0.760417  0.695238  0.849462
# 12  0.000000  0.222222  0.425414  0.729167  0.676190  0.000000

# %%
y_train
# Out:
# 52    1.000000
# 5     0.333333
# 24    0.666667
# 36    0.666667
# 44    1.000000
# 2     0.000000
# 49    1.000000
# 18    0.000000
# 8     0.000000
# 1     0.000000
# 29    0.666667
# 54    1.000000
# 51    1.000000
# 58    1.000000
# 30    0.666667
# 27    0.666667
# 0     0.000000
# 14    0.000000
# 41    0.666667
# 46    1.000000
# 55    1.000000
# 10    0.000000
# 3     0.333333
# 25    0.666667
# 33    0.666667
# 50    1.000000
# 13    0.000000
# 42    0.666667
# 6     0.333333
# 47    1.000000
# 48    1.000000
# 45    1.000000
# 39    0.666667
# 38    0.666667
# 16    0.000000
# 19    0.000000
# 43    1.000000
# 53    1.000000
# 21    0.000000
# 40    0.666667
# 32    0.666667
# 34    0.666667
# 7     0.333333
# 22    0.000000
# 11    0.000000
# 20    0.000000
# 9     0.000000
# 57    1.000000
# 28    0.666667
# 31    0.666667
# 15    0.000000
# 26    0.666667
# 35    0.666667
# Name: col-1, dtype: float64

# %%
y_test
# Out:
# 4     0.333333
# 23    0.000000
# 17    0.000000
# 56    1.000000
# 37    0.666667
# 12    0.000000
# Name: col-1, dtype: float64
